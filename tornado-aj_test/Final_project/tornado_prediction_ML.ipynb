# %%
# Import Dependancies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read Tornado data
csv_file = "data/1950-2019_all_tornadoes.csv"
df = pd.read_csv(csv_file)
df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 1           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 2           1  1950   1   3  1950-01-03  11:10:00   3  IL   17    1  ...
# 3           2  1950   1   3  1950-01-03  11:55:00   3  IL   17    2  ...
# 4           3  1950   1   3  1950-01-03  16:00:00   3  OH   39    1  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 66383  618537  2019  12  29  2019-12-29  16:03:00   3  MS   28    0  ...
# 66384  618538  2019  12  29  2019-12-29  16:13:00   3  MS   28    0  ...
# 66385  618539  2019  12  29  2019-12-29  16:32:00   3  MS   28    0  ...
# 66386  618540  2019  12  29  2019-12-29  17:13:00   3  MS   28    0  ...
# 66387  618541  2019  12  29  2019-12-29  18:50:00   3  AL    1    0  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0      9.50  150   2   0   1    0   0   0   0   0
# 1      6.20  150   2   1   2  189   0   0   0   0
# 2      3.30  100   2   1   2  119   0   0   0   0
# 3      3.60  130   1   1   1  135   0   0   0   0
# 4      0.10   10   1   1   1  161   0   0   0   0
# ...     ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 66383  7.70  900   1   1   1    7   0   0   0   0
# 66384  3.82  200   1   1   1   19   0   0   0   0
# 66385  2.61  200   1   1   1  105   0   0   0   0
# 66386  3.23  125   1   1   1  101   0   0   0   0
# 66387  5.07   50   1   1   1   83   0   0   0   0
#
# [66388 rows x 29 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df.dtypes
# Out:
# om         int64
# yr         int64
# mo         int64
# dy         int64
# date      object
# time      object
# tz         int64
# st        object
# stf        int64
# stn        int64
# mag        int64
# inj        int64
# fat        int64
# loss     float64
# closs    float64
# slat     float64
# slon     float64
# elat     float64
# elon     float64
# len      float64
# wid        int64
# ns         int64
# sn         int64
# sg         int64
# f1         int64
# f2         int64
# f3         int64
# f4         int64
# fc         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'ns', 'sn', 'sg', 'f1', 'f2', 'f3', 'f4', 'fc'],
#       dtype='object')

# %%
# Select tornado data for desired years
filtered_df = df.loc[df.yr >= 1995, :]
filtered_df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 34750       1  1995   1   6  1995-01-06  09:40:00   3  LA   22    1  ...
# 34751       2  1995   1   6  1995-01-06  11:05:00   3  LA   22    2  ...
# 34752       3  1995   1   6  1995-01-06  11:10:00   3  LA   22    3  ...
# 34753       4  1995   1   6  1995-01-06  20:10:00   3  SC   45    1  ...
# 34754       5  1995   1   6  1995-01-06  20:14:00   3  SC   45    2  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 66383  618537  2019  12  29  2019-12-29  16:03:00   3  MS   28    0  ...
# 66384  618538  2019  12  29  2019-12-29  16:13:00   3  MS   28    0  ...
# 66385  618539  2019  12  29  2019-12-29  16:32:00   3  MS   28    0  ...
# 66386  618540  2019  12  29  2019-12-29  17:13:00   3  MS   28    0  ...
# 66387  618541  2019  12  29  2019-12-29  18:50:00   3  AL    1    0  ...
#
#          len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 34750  15.00   20   1   1   1   59   0   0   0   0
# 34751   5.00   30   1   1   1   55   0   0   0   0
# 34752   0.20   20   1   1   1  113   0   0   0   0
# 34753   3.00  100   1   1   1   79   0   0   0   0
# 34754   0.20  100   1   1   1   39   0   0   0   0
# ...      ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 66383   7.70  900   1   1   1    7   0   0   0   0
# 66384   3.82  200   1   1   1   19   0   0   0   0
# 66385   2.61  200   1   1   1  105   0   0   0   0
# 66386   3.23  125   1   1   1  101   0   0   0   0
# 66387   5.07   50   1   1   1   83   0   0   0   0
#
# [31638 rows x 29 columns]

# %%
# Select derired columns
df1 = filtered_df[['yr', 'mo', 'st', 'mag', 'inj', 'fat',\
                   'loss', 'closs', 'len', 'wid', 'slat', 'slon']]
df1
# Out:
#          yr  mo  st  mag  inj  fat      loss  closs    len  wid     slat  \
# 34750  1995   1  LA    1    0    0       4.0    0.0  15.00   20  31.5200
# 34751  1995   1  LA    1    8    0       5.0    0.0   5.00   30  30.2300
# 34752  1995   1  LA    0    0    0       0.0    0.0   0.20   20  29.9700
# 34753  1995   1  SC    1    0    0       4.0    0.0   3.00  100  34.1300
# 34754  1995   1  SC    1    0    0       5.0    0.0   0.20  100  34.4000
# ...     ...  ..  ..  ...  ...  ...       ...    ...    ...  ...      ...
# 66383  2019  12  MS    1    0    0   75000.0    0.0   7.70  900  33.1628
# 66384  2019  12  MS    1    0    0   10000.0    0.0   3.82  200  33.2598
# 66385  2019  12  MS    0    0    0    5000.0    0.0   2.61  200  33.4720
# 66386  2019  12  MS    1    0    0  150000.0    0.0   3.23  125  32.5268
# 66387  2019  12  AL    0    0    0       0.0    0.0   5.07   50  34.7541
#
#           slon
# 34750 -92.2300
# 34751 -92.1800
# 34752 -92.1700
# 34753 -81.2300
# 34754 -81.0700
# ...        ...
# 66383 -89.4323
# 66384 -89.2778
# 66385 -89.0315
# 66386 -89.1628
# 66387 -87.0777
#
# [31638 rows x 12 columns]

# %%
df1.reset_index(inplace = True, drop = True)
df1
# Out:
#          yr  mo  st  mag  inj  fat      loss  closs    len  wid     slat  \
# 0      1995   1  LA    1    0    0       4.0    0.0  15.00   20  31.5200
# 1      1995   1  LA    1    8    0       5.0    0.0   5.00   30  30.2300
# 2      1995   1  LA    0    0    0       0.0    0.0   0.20   20  29.9700
# 3      1995   1  SC    1    0    0       4.0    0.0   3.00  100  34.1300
# 4      1995   1  SC    1    0    0       5.0    0.0   0.20  100  34.4000
# ...     ...  ..  ..  ...  ...  ...       ...    ...    ...  ...      ...
# 31633  2019  12  MS    1    0    0   75000.0    0.0   7.70  900  33.1628
# 31634  2019  12  MS    1    0    0   10000.0    0.0   3.82  200  33.2598
# 31635  2019  12  MS    0    0    0    5000.0    0.0   2.61  200  33.4720
# 31636  2019  12  MS    1    0    0  150000.0    0.0   3.23  125  32.5268
# 31637  2019  12  AL    0    0    0       0.0    0.0   5.07   50  34.7541
#
#           slon
# 0     -92.2300
# 1     -92.1800
# 2     -92.1700
# 3     -81.2300
# 4     -81.0700
# ...        ...
# 31633 -89.4323
# 31634 -89.2778
# 31635 -89.0315
# 31636 -89.1628
# 31637 -87.0777
#
# [31638 rows x 12 columns]

# %%
# States Data
data = {'StName':['Alabama',
'Alaska',
'Arizona',
'Arkansas',
'California',
'Colorado',
'Connecticut',
'Delaware',
'Florida',
'Georgia',
'Hawaii',
'Idaho',
'Illinois',
'Indiana',
'Iowa',
'Kansas',
'Kentucky',
'Louisiana',
'Maine',
'Maryland',
'Massachusetts',
'Michigan',
'Minnesota',
'Mississippi',
'Missouri',
'Montana',
'Nebraska',
'Nevada',
'New Hampshire',
'New Jersey',
'New Mexico',
'New York',
'North Carolina',
'North Dakota',
'Ohio',
'Oklahoma',
'Oregon',
'Pennsylvania',
'Rhode Island',
'South Carolina',
'South Dakota',
'Tennessee',
'Texas',
'Utah',
'Vermont',
'Virginia',
'Washington',
'West Virginia',
'Wisconsin',
'Wyoming']}

states_df = pd.DataFrame(data)
cw_location = 'http://app02.clerk.org/menu/ccis/Help/CCIS%20Codes/'
cw_filename = 'state_codes.html'

states = pd.read_html(cw_location + cw_filename)[0]
state_code_map = dict(zip(states['Description'], 
                          states['Code']))
states_df['StAbbr'] = states_df['StName'].map(state_code_map)
code_state_map = dict(zip(states['Code'],
                          states['Description']))
states_df['StNameAgain'] = states_df['StAbbr'].map(code_state_map)
states_df = states_df.rename(columns={'stName': 'State_Name', 'StAbbr': 'st'})
states_df.head()
# Out:
#        StName  st StNameAgain
# 0     Alabama  AL     Alabama
# 1      Alaska  AK      Alaska
# 2     Arizona  AZ     Arizona
# 3    Arkansas  AR    Arkansas
# 4  California  CA  California

# %%
states_df.columns
# Out:
# Index(['StName', 'st', 'StNameAgain'], dtype='object')

# %%
# Merge dataframes
new_df2 = pd.merge(df1, states_df, on='st', how='left')
# new_df2
df3 = new_df2[[
'yr',
'mo',
'st',
'mag',
'inj',
'fat',
'loss',
'closs',
'len',
'wid',
'slat',
'slon',
'StName']]
df3
# Out:
#          yr  mo  st  mag  inj  fat      loss  closs    len  wid     slat  \
# 0      1995   1  LA    1    0    0       4.0    0.0  15.00   20  31.5200
# 1      1995   1  LA    1    8    0       5.0    0.0   5.00   30  30.2300
# 2      1995   1  LA    0    0    0       0.0    0.0   0.20   20  29.9700
# 3      1995   1  SC    1    0    0       4.0    0.0   3.00  100  34.1300
# 4      1995   1  SC    1    0    0       5.0    0.0   0.20  100  34.4000
# ...     ...  ..  ..  ...  ...  ...       ...    ...    ...  ...      ...
# 31633  2019  12  MS    1    0    0   75000.0    0.0   7.70  900  33.1628
# 31634  2019  12  MS    1    0    0   10000.0    0.0   3.82  200  33.2598
# 31635  2019  12  MS    0    0    0    5000.0    0.0   2.61  200  33.4720
# 31636  2019  12  MS    1    0    0  150000.0    0.0   3.23  125  32.5268
# 31637  2019  12  AL    0    0    0       0.0    0.0   5.07   50  34.7541
#
#           slon          StName
# 0     -92.2300       Louisiana
# 1     -92.1800       Louisiana
# 2     -92.1700       Louisiana
# 3     -81.2300  South Carolina
# 4     -81.0700  South Carolina
# ...        ...             ...
# 31633 -89.4323     Mississippi
# 31634 -89.2778     Mississippi
# 31635 -89.0315     Mississippi
# 31636 -89.1628     Mississippi
# 31637 -87.0777         Alabama
#
# [31638 rows x 13 columns]

# %%
df_clean = df3.copy()
df_clean
# Out:
#          yr  mo  st  mag  inj  fat      loss  closs    len  wid     slat  \
# 0      1995   1  LA    1    0    0       4.0    0.0  15.00   20  31.5200
# 1      1995   1  LA    1    8    0       5.0    0.0   5.00   30  30.2300
# 2      1995   1  LA    0    0    0       0.0    0.0   0.20   20  29.9700
# 3      1995   1  SC    1    0    0       4.0    0.0   3.00  100  34.1300
# 4      1995   1  SC    1    0    0       5.0    0.0   0.20  100  34.4000
# ...     ...  ..  ..  ...  ...  ...       ...    ...    ...  ...      ...
# 31633  2019  12  MS    1    0    0   75000.0    0.0   7.70  900  33.1628
# 31634  2019  12  MS    1    0    0   10000.0    0.0   3.82  200  33.2598
# 31635  2019  12  MS    0    0    0    5000.0    0.0   2.61  200  33.4720
# 31636  2019  12  MS    1    0    0  150000.0    0.0   3.23  125  32.5268
# 31637  2019  12  AL    0    0    0       0.0    0.0   5.07   50  34.7541
#
#           slon          StName
# 0     -92.2300       Louisiana
# 1     -92.1800       Louisiana
# 2     -92.1700       Louisiana
# 3     -81.2300  South Carolina
# 4     -81.0700  South Carolina
# ...        ...             ...
# 31633 -89.4323     Mississippi
# 31634 -89.2778     Mississippi
# 31635 -89.0315     Mississippi
# 31636 -89.1628     Mississippi
# 31637 -87.0777         Alabama
#
# [31638 rows x 13 columns]

# %%
import seaborn as sns
sns.countplot(df_clean["mag"], label="Count")
plt.show()
# Out:
# /Users/seltsam/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Select the rows where magnitude >= 0
df_magfilt = df_clean[df_clean['mag'] >= 0]
df_magfilt
# Out:
#          yr  mo  st  mag  inj  fat      loss  closs    len  wid     slat  \
# 0      1995   1  LA    1    0    0       4.0    0.0  15.00   20  31.5200
# 1      1995   1  LA    1    8    0       5.0    0.0   5.00   30  30.2300
# 2      1995   1  LA    0    0    0       0.0    0.0   0.20   20  29.9700
# 3      1995   1  SC    1    0    0       4.0    0.0   3.00  100  34.1300
# 4      1995   1  SC    1    0    0       5.0    0.0   0.20  100  34.4000
# ...     ...  ..  ..  ...  ...  ...       ...    ...    ...  ...      ...
# 31633  2019  12  MS    1    0    0   75000.0    0.0   7.70  900  33.1628
# 31634  2019  12  MS    1    0    0   10000.0    0.0   3.82  200  33.2598
# 31635  2019  12  MS    0    0    0    5000.0    0.0   2.61  200  33.4720
# 31636  2019  12  MS    1    0    0  150000.0    0.0   3.23  125  32.5268
# 31637  2019  12  AL    0    0    0       0.0    0.0   5.07   50  34.7541
#
#           slon          StName
# 0     -92.2300       Louisiana
# 1     -92.1800       Louisiana
# 2     -92.1700       Louisiana
# 3     -81.2300  South Carolina
# 4     -81.0700  South Carolina
# ...        ...             ...
# 31633 -89.4323     Mississippi
# 31634 -89.2778     Mississippi
# 31635 -89.0315     Mississippi
# 31636 -89.1628     Mississippi
# 31637 -87.0777         Alabama
#
# [31340 rows x 13 columns]

# %%
sns.countplot(df_magfilt["mag"], label="Count")
plt.show()
# Out:
# /Users/seltsam/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_magfilt['adjusted magnitude'] = df_magfilt['mag']
df_magfilt = df_magfilt.replace({'adjusted magnitude': {3: 2, 4: 2, 5:2}})
df_magfilt
# Out:
# <ipython-input-15-42069892d478>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_magfilt['adjusted magnitude'] = df_magfilt['mag']
#          yr  mo  st  mag  inj  fat      loss  closs    len  wid     slat  \
# 0      1995   1  LA    1    0    0       4.0    0.0  15.00   20  31.5200
# 1      1995   1  LA    1    8    0       5.0    0.0   5.00   30  30.2300
# 2      1995   1  LA    0    0    0       0.0    0.0   0.20   20  29.9700
# 3      1995   1  SC    1    0    0       4.0    0.0   3.00  100  34.1300
# 4      1995   1  SC    1    0    0       5.0    0.0   0.20  100  34.4000
# ...     ...  ..  ..  ...  ...  ...       ...    ...    ...  ...      ...
# 31633  2019  12  MS    1    0    0   75000.0    0.0   7.70  900  33.1628
# 31634  2019  12  MS    1    0    0   10000.0    0.0   3.82  200  33.2598
# 31635  2019  12  MS    0    0    0    5000.0    0.0   2.61  200  33.4720
# 31636  2019  12  MS    1    0    0  150000.0    0.0   3.23  125  32.5268
# 31637  2019  12  AL    0    0    0       0.0    0.0   5.07   50  34.7541
#
#           slon          StName  adjusted magnitude
# 0     -92.2300       Louisiana                   1
# 1     -92.1800       Louisiana                   1
# 2     -92.1700       Louisiana                   0
# 3     -81.2300  South Carolina                   1
# 4     -81.0700  South Carolina                   1
# ...        ...             ...                 ...
# 31633 -89.4323     Mississippi                   1
# 31634 -89.2778     Mississippi                   1
# 31635 -89.0315     Mississippi                   0
# 31636 -89.1628     Mississippi                   1
# 31637 -87.0777         Alabama                   0
#
# [31340 rows x 14 columns]

# %%
df_magfilt["adjusted magnitude"].value_counts()
# Out:
# 0    18557
# 1     9228
# 2     3555
# Name: adjusted magnitude, dtype: int64

# %%
df_magfilt["mag"].max()
# Out:
# 5

# %%
df_magfilt.columns
# Out:
# Index(['yr', 'mo', 'st', 'mag', 'inj', 'fat', 'loss', 'closs', 'len', 'wid',
#        'slat', 'slon', 'StName', 'adjusted magnitude'],
#       dtype='object')

# %% [markdown]
# ## Machine Learning

# %%
cleaned = df_magfilt[["yr", "mo", "fat", "loss", "len", "wid", "slat", "slon", "StName", "mag"]]
cleaned
# Out:
#          yr  mo  fat      loss    len  wid     slat     slon          StName  \
# 0      1995   1    0       4.0  15.00   20  31.5200 -92.2300       Louisiana
# 1      1995   1    0       5.0   5.00   30  30.2300 -92.1800       Louisiana
# 2      1995   1    0       0.0   0.20   20  29.9700 -92.1700       Louisiana
# 3      1995   1    0       4.0   3.00  100  34.1300 -81.2300  South Carolina
# 4      1995   1    0       5.0   0.20  100  34.4000 -81.0700  South Carolina
# ...     ...  ..  ...       ...    ...  ...      ...      ...             ...
# 31633  2019  12    0   75000.0   7.70  900  33.1628 -89.4323     Mississippi
# 31634  2019  12    0   10000.0   3.82  200  33.2598 -89.2778     Mississippi
# 31635  2019  12    0    5000.0   2.61  200  33.4720 -89.0315     Mississippi
# 31636  2019  12    0  150000.0   3.23  125  32.5268 -89.1628     Mississippi
# 31637  2019  12    0       0.0   5.07   50  34.7541 -87.0777         Alabama
#
#        mag
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
# ...    ...
# 31633    1
# 31634    1
# 31635    0
# 31636    1
# 31637    0
#
# [31340 rows x 10 columns]

# %%
# data is not balanced
from pandas.plotting import scatter_matrix 

scatter_matrix(cleaned.drop('mag', axis=1), figsize=(10,5))
plt.show()

# %% [markdown]
# ## Predict Tornado Category (magnitude)

# %%
# Choose our features
X = cleaned[["fat", "len", "wid", "slat", "slon"]]
X
# Out:
#        fat    len  wid     slat     slon
# 0        0  15.00   20  31.5200 -92.2300
# 1        0   5.00   30  30.2300 -92.1800
# 2        0   0.20   20  29.9700 -92.1700
# 3        0   3.00  100  34.1300 -81.2300
# 4        0   0.20  100  34.4000 -81.0700
# ...    ...    ...  ...      ...      ...
# 31633    0   7.70  900  33.1628 -89.4323
# 31634    0   3.82  200  33.2598 -89.2778
# 31635    0   2.61  200  33.4720 -89.0315
# 31636    0   3.23  125  32.5268 -89.1628
# 31637    0   5.07   50  34.7541 -87.0777
#
# [31340 rows x 5 columns]

# %%
# Choose our label
y = cleaned['mag']
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 31633    1
# 31634    1
# 31635    0
# 31636    1
# 31637    0
# Name: mag, Length: 31340, dtype: int64

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Create training and testing sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ### Output CSV file for weights for app

# %%
# keep columns used as predictors of cleaned dataframe

train_output = X_train[["fat", "len", "wid", "slat", "slon"]]
train_output.head()
# Out:
#        fat    len  wid    slat      slon
# 5173     0  22.00    0  31.970  -91.6000
# 27587    0   0.29  900  31.804  -83.6168
# 6151     0   0.00   30  41.080  -82.4000
# 25423    0   0.20   30  30.070  -91.2800
# 9190     0   0.10   50  48.400 -107.2000

# %%
# output to csv

train_output.to_csv(r'cleaned.csv',index=False)

# %% [markdown]
# ### Apply Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Build Models

# %%
## Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_scaled, y_train)

print('Accuracy of Logistic Regression on training data', logreg.score(X_train_scaled, y_train))
print('Accuracy of Logistic Regression on testing data', logreg.score(X_test_scaled, y_test))
# Out:
# Accuracy of Logistic Regression on training data 0.6704530950861519
# Accuracy of Logistic Regression on testing data 0.6751754945756222
# /Users/seltsam/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
## Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train_scaled, y_train)

print('Accuracy of Decision Tree on training', dt.score(X_train_scaled, y_train))
print('Accuracy of Decision Tree on testing', dt.score(X_test_scaled, y_test))
# Out:
# Accuracy of Decision Tree on training 0.999617102744097
# Accuracy of Decision Tree on testing 0.6353541799617103

# %%
# Setting max decision tree depth to help avoid overfitting
dt2 = DecisionTreeClassifier(max_depth=5)
dt2.fit(X_train_scaled, y_train)
print('Accuracy of Decision tree on training', dt2.score(X_train_scaled, y_train))
print('Accuracy of Decision tree on testing', dt2.score(X_test_scaled, y_test))
# Out:
# Accuracy of Decision tree on training 0.7070835992342055
# Accuracy of Decision tree on testing 0.7101467772814295

# %%
# K-nearest neighbor 
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train_scaled, y_train)
print('Accuracy of KNN on training', knn.score(X_train_scaled, y_train))
print('Accuracy of KNN on testing', knn.score(X_test_scaled, y_test))
# Out:
# Accuracy of KNN on training 0.772814294830887
# Accuracy of KNN on testing 0.6871729419272495

# %%
# Linear Discriminant Analysis 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(X_train_scaled,y_train)
print('Accuracy of Linear Discriminant Analysis on training', lda.score(X_train_scaled, y_train))
print('Accuracy of Linear Discriminant Analysis on testing', lda.score(X_test_scaled, y_test))
# Out:
# Accuracy of Linear Discriminant Analysis on training 0.6458625824292704
# Accuracy of Linear Discriminant Analysis on testing 0.6479897894065092

# %%
# Gaussian Naive Bayes 
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train_scaled, y_train)
print('Accuracy of GNB on training', gnb.score(X_train_scaled, y_train))
print('Accuracy of GNB on testing', gnb.score(X_test_scaled, y_test))
# Out:
# Accuracy of GNB on training 0.6623271644330994
# Accuracy of GNB on testing 0.6638162093171666

# %%
# Support Vector Machine
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train_scaled, y_train)
print('Accuracy of SVM on training', svm.score(X_train_scaled, y_train))
print('Accuracy of SVM on testing', svm.score(X_test_scaled, y_test))
# Out:
# Accuracy of SVM on training 0.6848755583918316
# Accuracy of SVM on testing 0.6918953414167198

# %% [markdown]
# ### Save and load the best model

# %%
import pickle

# %%
pickle.dump(dt2, open('model.pkl','wb'))

# %%
# Loading model to compare the results
model = pickle.load( open('model.pkl','rb'))

# %% [markdown]
# ### Make Prediction on tornado category (magnitude)

# %%
user_input = [[50, 100, 900, 31.51, -93.92,]]
inputdf = pd.DataFrame(user_input,columns=["fat", "len", "wid", "slat", "slon"])
original_df = X.copy()
reference = original_df.append(inputdf).reset_index()
new_df = reference[["fat", "len", "wid", "slat", "slon"]]
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(new_df)
[list(scaled_df[len(scaled_df)-1])]
# scaled_df
# Out:
# [[0.31645569620253167,
#   0.6712760958582265,
#   0.19667832167832167,
#   0.5163880694854146,
#   0.425671130679386]]

# %%
model.predict([list(scaled_df[len(scaled_df)-1])])
# Out:
# array([3])
