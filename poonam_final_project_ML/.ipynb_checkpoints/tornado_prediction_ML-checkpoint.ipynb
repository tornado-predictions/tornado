# %%
# Import Dependancies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read Tornado data
csv_file = "data/1950-2019_all_tornadoes.csv"
df = pd.read_csv(csv_file)
df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 1           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 2           1  1950   1   3  1950-01-03  11:10:00   3  IL   17    1  ...
# 3           2  1950   1   3  1950-01-03  11:55:00   3  IL   17    2  ...
# 4           3  1950   1   3  1950-01-03  16:00:00   3  OH   39    1  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 66383  618537  2019  12  29  2019-12-29  16:03:00   3  MS   28    0  ...
# 66384  618538  2019  12  29  2019-12-29  16:13:00   3  MS   28    0  ...
# 66385  618539  2019  12  29  2019-12-29  16:32:00   3  MS   28    0  ...
# 66386  618540  2019  12  29  2019-12-29  17:13:00   3  MS   28    0  ...
# 66387  618541  2019  12  29  2019-12-29  18:50:00   3  AL    1    0  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0      9.50  150   2   0   1    0   0   0   0   0
# 1      6.20  150   2   1   2  189   0   0   0   0
# 2      3.30  100   2   1   2  119   0   0   0   0
# 3      3.60  130   1   1   1  135   0   0   0   0
# 4      0.10   10   1   1   1  161   0   0   0   0
# ...     ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 66383  7.70  900   1   1   1    7   0   0   0   0
# 66384  3.82  200   1   1   1   19   0   0   0   0
# 66385  2.61  200   1   1   1  105   0   0   0   0
# 66386  3.23  125   1   1   1  101   0   0   0   0
# 66387  5.07   50   1   1   1   83   0   0   0   0
#
# [66388 rows x 29 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df.dtypes
# Out:
# om         int64
# yr         int64
# mo         int64
# dy         int64
# date      object
# time      object
# tz         int64
# st        object
# stf        int64
# stn        int64
# mag        int64
# inj        int64
# fat        int64
# loss     float64
# closs    float64
# slat     float64
# slon     float64
# elat     float64
# elon     float64
# len      float64
# wid        int64
# ns         int64
# sn         int64
# sg         int64
# f1         int64
# f2         int64
# f3         int64
# f4         int64
# fc         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'ns', 'sn', 'sg', 'f1', 'f2', 'f3', 'f4', 'fc'],
#       dtype='object')

# %%
# Select tornado data for desired years
filtered_df = df.loc[df.yr >= 2016, :]
filtered_df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 61217  613495  2016   1   6  2016-01-06  10:50:00   3  CA    6    0  ...
# 61218  613496  2016   1   8  2016-01-08  05:30:00   3  FL   12    0  ...
# 61219  613497  2016   1   9  2016-01-09  17:45:00   3  FL   12    0  ...
# 61220  613498  2016   1  15  2016-01-15  10:10:00   3  FL   12    0  ...
# 61221  613499  2016   1  17  2016-01-17  02:10:00   3  FL   12    0  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 66383  618537  2019  12  29  2019-12-29  16:03:00   3  MS   28    0  ...
# 66384  618538  2019  12  29  2019-12-29  16:13:00   3  MS   28    0  ...
# 66385  618539  2019  12  29  2019-12-29  16:32:00   3  MS   28    0  ...
# 66386  618540  2019  12  29  2019-12-29  17:13:00   3  MS   28    0  ...
# 66387  618541  2019  12  29  2019-12-29  18:50:00   3  AL    1    0  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 61217  0.61   20   1   1   1   69   0   0   0   0
# 61218  0.09   20   1   1   1   87   0   0   0   0
# 61219  3.35  182   1   1   1   71   0   0   0   0
# 61220  0.19   45   1   1   1   71   0   0   0   0
# 61221  1.15  350   1   1   1  115   0   0   0   0
# ...     ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 66383  7.70  900   1   1   1    7   0   0   0   0
# 66384  3.82  200   1   1   1   19   0   0   0   0
# 66385  2.61  200   1   1   1  105   0   0   0   0
# 66386  3.23  125   1   1   1  101   0   0   0   0
# 66387  5.07   50   1   1   1   83   0   0   0   0
#
# [5171 rows x 29 columns]

# %%
# Select derired columns
df1 = filtered_df[['yr', 'mo', 'st', 'mag', 'inj', 'fat',\
                   'loss', 'closs', 'len', 'wid', 'slat', 'slon']]
df1
# Out:
#          yr  mo  st  mag  inj  fat        loss    closs   len  wid     slat  \
# 61217  2016   1  CA    0    0    0         0.0  75000.0  0.61   20  36.9381
# 61218  2016   1  FL    0    0    0      2000.0      0.0  0.09   20  24.7315
# 61219  2016   1  FL    2    3    0   2000000.0      0.0  3.35  182  26.5700
# 61220  2016   1  FL    1    0    0    200000.0      0.0  0.19   45  26.5503
# 61221  2016   1  FL    2    2    0  12000000.0      0.0  1.15  350  27.2530
# ...     ...  ..  ..  ...  ...  ...         ...      ...   ...  ...      ...
# 66383  2019  12  MS    1    0    0     75000.0      0.0  7.70  900  33.1628
# 66384  2019  12  MS    1    0    0     10000.0      0.0  3.82  200  33.2598
# 66385  2019  12  MS    0    0    0      5000.0      0.0  2.61  200  33.4720
# 66386  2019  12  MS    1    0    0    150000.0      0.0  3.23  125  32.5268
# 66387  2019  12  AL    0    0    0         0.0      0.0  5.07   50  34.7541
#
#            slon
# 61217 -121.3815
# 61218  -81.0139
# 61219  -82.0370
# 61220  -81.9126
# 61221  -82.5396
# ...         ...
# 66383  -89.4323
# 66384  -89.2778
# 66385  -89.0315
# 66386  -89.1628
# 66387  -87.0777
#
# [5171 rows x 12 columns]

# %%
df1.reset_index(inplace = True, drop = True)
df1
# Out:
#         yr  mo  st  mag  inj  fat        loss    closs   len  wid     slat  \
# 0     2016   1  CA    0    0    0         0.0  75000.0  0.61   20  36.9381
# 1     2016   1  FL    0    0    0      2000.0      0.0  0.09   20  24.7315
# 2     2016   1  FL    2    3    0   2000000.0      0.0  3.35  182  26.5700
# 3     2016   1  FL    1    0    0    200000.0      0.0  0.19   45  26.5503
# 4     2016   1  FL    2    2    0  12000000.0      0.0  1.15  350  27.2530
# ...    ...  ..  ..  ...  ...  ...         ...      ...   ...  ...      ...
# 5166  2019  12  MS    1    0    0     75000.0      0.0  7.70  900  33.1628
# 5167  2019  12  MS    1    0    0     10000.0      0.0  3.82  200  33.2598
# 5168  2019  12  MS    0    0    0      5000.0      0.0  2.61  200  33.4720
# 5169  2019  12  MS    1    0    0    150000.0      0.0  3.23  125  32.5268
# 5170  2019  12  AL    0    0    0         0.0      0.0  5.07   50  34.7541
#
#           slon
# 0    -121.3815
# 1     -81.0139
# 2     -82.0370
# 3     -81.9126
# 4     -82.5396
# ...        ...
# 5166  -89.4323
# 5167  -89.2778
# 5168  -89.0315
# 5169  -89.1628
# 5170  -87.0777
#
# [5171 rows x 12 columns]

# %%
# States Data
data = {'StName':['Alabama',
'Alaska',
'Arizona',
'Arkansas',
'California',
'Colorado',
'Connecticut',
'Delaware',
'Florida',
'Georgia',
'Hawaii',
'Idaho',
'Illinois',
'Indiana',
'Iowa',
'Kansas',
'Kentucky',
'Louisiana',
'Maine',
'Maryland',
'Massachusetts',
'Michigan',
'Minnesota',
'Mississippi',
'Missouri',
'Montana',
'Nebraska',
'Nevada',
'New Hampshire',
'New Jersey',
'New Mexico',
'New York',
'North Carolina',
'North Dakota',
'Ohio',
'Oklahoma',
'Oregon',
'Pennsylvania',
'Rhode Island',
'South Carolina',
'South Dakota',
'Tennessee',
'Texas',
'Utah',
'Vermont',
'Virginia',
'Washington',
'West Virginia',
'Wisconsin',
'Wyoming']}

states_df = pd.DataFrame(data)
cw_location = 'http://app02.clerk.org/menu/ccis/Help/CCIS%20Codes/'
cw_filename = 'state_codes.html'

states = pd.read_html(cw_location + cw_filename)[0]
state_code_map = dict(zip(states['Description'], 
                          states['Code']))
states_df['StAbbr'] = states_df['StName'].map(state_code_map)
code_state_map = dict(zip(states['Code'],
                          states['Description']))
states_df['StNameAgain'] = states_df['StAbbr'].map(code_state_map)
states_df = states_df.rename(columns={'stName': 'State_Name', 'StAbbr': 'st'})
states_df.head()
# Out:
#        StName  st StNameAgain
# 0     Alabama  AL     Alabama
# 1      Alaska  AK      Alaska
# 2     Arizona  AZ     Arizona
# 3    Arkansas  AR    Arkansas
# 4  California  CA  California

# %%
states_df.columns
# Out:
# Index(['StName', 'st', 'StNameAgain'], dtype='object')

# %%
# Merge dataframes
new_df2 = pd.merge(df1, states_df, on='st', how='left')
# new_df2
df3 = new_df2[[
'yr',
'mo',
'st',
'mag',
'inj',
'fat',
'loss',
'closs',
'len',
'wid',
'slat',
'slon',
'StName']]
df3
# Out:
#         yr  mo  st  mag  inj  fat        loss    closs   len  wid     slat  \
# 0     2016   1  CA    0    0    0         0.0  75000.0  0.61   20  36.9381
# 1     2016   1  FL    0    0    0      2000.0      0.0  0.09   20  24.7315
# 2     2016   1  FL    2    3    0   2000000.0      0.0  3.35  182  26.5700
# 3     2016   1  FL    1    0    0    200000.0      0.0  0.19   45  26.5503
# 4     2016   1  FL    2    2    0  12000000.0      0.0  1.15  350  27.2530
# ...    ...  ..  ..  ...  ...  ...         ...      ...   ...  ...      ...
# 5166  2019  12  MS    1    0    0     75000.0      0.0  7.70  900  33.1628
# 5167  2019  12  MS    1    0    0     10000.0      0.0  3.82  200  33.2598
# 5168  2019  12  MS    0    0    0      5000.0      0.0  2.61  200  33.4720
# 5169  2019  12  MS    1    0    0    150000.0      0.0  3.23  125  32.5268
# 5170  2019  12  AL    0    0    0         0.0      0.0  5.07   50  34.7541
#
#           slon       StName
# 0    -121.3815   California
# 1     -81.0139      Florida
# 2     -82.0370      Florida
# 3     -81.9126      Florida
# 4     -82.5396      Florida
# ...        ...          ...
# 5166  -89.4323  Mississippi
# 5167  -89.2778  Mississippi
# 5168  -89.0315  Mississippi
# 5169  -89.1628  Mississippi
# 5170  -87.0777      Alabama
#
# [5171 rows x 13 columns]

# %%
df_clean = df3.copy()
df_clean
# Out:
#         yr  mo  st  mag  inj  fat        loss    closs   len  wid     slat  \
# 0     2016   1  CA    0    0    0         0.0  75000.0  0.61   20  36.9381
# 1     2016   1  FL    0    0    0      2000.0      0.0  0.09   20  24.7315
# 2     2016   1  FL    2    3    0   2000000.0      0.0  3.35  182  26.5700
# 3     2016   1  FL    1    0    0    200000.0      0.0  0.19   45  26.5503
# 4     2016   1  FL    2    2    0  12000000.0      0.0  1.15  350  27.2530
# ...    ...  ..  ..  ...  ...  ...         ...      ...   ...  ...      ...
# 5166  2019  12  MS    1    0    0     75000.0      0.0  7.70  900  33.1628
# 5167  2019  12  MS    1    0    0     10000.0      0.0  3.82  200  33.2598
# 5168  2019  12  MS    0    0    0      5000.0      0.0  2.61  200  33.4720
# 5169  2019  12  MS    1    0    0    150000.0      0.0  3.23  125  32.5268
# 5170  2019  12  AL    0    0    0         0.0      0.0  5.07   50  34.7541
#
#           slon       StName
# 0    -121.3815   California
# 1     -81.0139      Florida
# 2     -82.0370      Florida
# 3     -81.9126      Florida
# 4     -82.5396      Florida
# ...        ...          ...
# 5166  -89.4323  Mississippi
# 5167  -89.2778  Mississippi
# 5168  -89.0315  Mississippi
# 5169  -89.1628  Mississippi
# 5170  -87.0777      Alabama
#
# [5171 rows x 13 columns]

# %%
import seaborn as sns
sns.countplot(df_clean["mag"], label="Count")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Select the rows where magnitude >= 0
df_magfilt = df_clean[df_clean['mag'] >= 0]
df_magfilt
# Out:
#         yr  mo  st  mag  inj  fat        loss    closs   len  wid     slat  \
# 0     2016   1  CA    0    0    0         0.0  75000.0  0.61   20  36.9381
# 1     2016   1  FL    0    0    0      2000.0      0.0  0.09   20  24.7315
# 2     2016   1  FL    2    3    0   2000000.0      0.0  3.35  182  26.5700
# 3     2016   1  FL    1    0    0    200000.0      0.0  0.19   45  26.5503
# 4     2016   1  FL    2    2    0  12000000.0      0.0  1.15  350  27.2530
# ...    ...  ..  ..  ...  ...  ...         ...      ...   ...  ...      ...
# 5166  2019  12  MS    1    0    0     75000.0      0.0  7.70  900  33.1628
# 5167  2019  12  MS    1    0    0     10000.0      0.0  3.82  200  33.2598
# 5168  2019  12  MS    0    0    0      5000.0      0.0  2.61  200  33.4720
# 5169  2019  12  MS    1    0    0    150000.0      0.0  3.23  125  32.5268
# 5170  2019  12  AL    0    0    0         0.0      0.0  5.07   50  34.7541
#
#           slon       StName
# 0    -121.3815   California
# 1     -81.0139      Florida
# 2     -82.0370      Florida
# 3     -81.9126      Florida
# 4     -82.5396      Florida
# ...        ...          ...
# 5166  -89.4323  Mississippi
# 5167  -89.2778  Mississippi
# 5168  -89.0315  Mississippi
# 5169  -89.1628  Mississippi
# 5170  -87.0777      Alabama
#
# [4873 rows x 13 columns]

# %%
sns.countplot(df_magfilt["mag"], label="Count")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_magfilt['adjusted magnitude'] = df_magfilt['mag']
df_magfilt = df_magfilt.replace({'adjusted magnitude': {3: 2, 4: 2, 5:2}})
df_magfilt
# Out:
# <ipython-input-15-42069892d478>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_magfilt['adjusted magnitude'] = df_magfilt['mag']
#         yr  mo  st  mag  inj  fat        loss    closs   len  wid     slat  \
# 0     2016   1  CA    0    0    0         0.0  75000.0  0.61   20  36.9381
# 1     2016   1  FL    0    0    0      2000.0      0.0  0.09   20  24.7315
# 2     2016   1  FL    2    3    0   2000000.0      0.0  3.35  182  26.5700
# 3     2016   1  FL    1    0    0    200000.0      0.0  0.19   45  26.5503
# 4     2016   1  FL    2    2    0  12000000.0      0.0  1.15  350  27.2530
# ...    ...  ..  ..  ...  ...  ...         ...      ...   ...  ...      ...
# 5166  2019  12  MS    1    0    0     75000.0      0.0  7.70  900  33.1628
# 5167  2019  12  MS    1    0    0     10000.0      0.0  3.82  200  33.2598
# 5168  2019  12  MS    0    0    0      5000.0      0.0  2.61  200  33.4720
# 5169  2019  12  MS    1    0    0    150000.0      0.0  3.23  125  32.5268
# 5170  2019  12  AL    0    0    0         0.0      0.0  5.07   50  34.7541
#
#           slon       StName  adjusted magnitude
# 0    -121.3815   California                   0
# 1     -81.0139      Florida                   0
# 2     -82.0370      Florida                   2
# 3     -81.9126      Florida                   1
# 4     -82.5396      Florida                   2
# ...        ...          ...                 ...
# 5166  -89.4323  Mississippi                   1
# 5167  -89.2778  Mississippi                   1
# 5168  -89.0315  Mississippi                   0
# 5169  -89.1628  Mississippi                   1
# 5170  -87.0777      Alabama                   0
#
# [4873 rows x 14 columns]

# %%
df_magfilt["adjusted magnitude"].value_counts()
# Out:
# 0    2461
# 1    1881
# 2     531
# Name: adjusted magnitude, dtype: int64

# %%
df_magfilt["mag"].max()
# Out:
# 4

# %%
df_magfilt.columns
# Out:
# Index(['yr', 'mo', 'st', 'mag', 'inj', 'fat', 'loss', 'closs', 'len', 'wid',
#        'slat', 'slon', 'StName', 'adjusted magnitude'],
#       dtype='object')

# %% [markdown]
# ## Machine Learning

# %%
cleaned = df_magfilt[["yr", "mo", "loss", "len", "wid", "slat", "slon", "StName", "adjusted magnitude"]]
cleaned
# Out:
#         yr  mo        loss   len  wid     slat      slon       StName  \
# 0     2016   1         0.0  0.61   20  36.9381 -121.3815   California
# 1     2016   1      2000.0  0.09   20  24.7315  -81.0139      Florida
# 2     2016   1   2000000.0  3.35  182  26.5700  -82.0370      Florida
# 3     2016   1    200000.0  0.19   45  26.5503  -81.9126      Florida
# 4     2016   1  12000000.0  1.15  350  27.2530  -82.5396      Florida
# ...    ...  ..         ...   ...  ...      ...       ...          ...
# 5166  2019  12     75000.0  7.70  900  33.1628  -89.4323  Mississippi
# 5167  2019  12     10000.0  3.82  200  33.2598  -89.2778  Mississippi
# 5168  2019  12      5000.0  2.61  200  33.4720  -89.0315  Mississippi
# 5169  2019  12    150000.0  3.23  125  32.5268  -89.1628  Mississippi
# 5170  2019  12         0.0  5.07   50  34.7541  -87.0777      Alabama
#
#       adjusted magnitude
# 0                      0
# 1                      0
# 2                      2
# 3                      1
# 4                      2
# ...                  ...
# 5166                   1
# 5167                   1
# 5168                   0
# 5169                   1
# 5170                   0
#
# [4873 rows x 9 columns]

# %%
# data is not balanced
from pandas.plotting import scatter_matrix 

scatter_matrix(cleaned.drop('adjusted magnitude', axis=1), figsize=(10,5))
plt.show()

# %% [markdown]
# ## Predict Tornado Category (magnitude)

# %%
# Choose our features
X = cleaned[["mo", "len", "wid", "slat", "slon"]]
X
# Out:
#       mo   len  wid     slat      slon
# 0      1  0.61   20  36.9381 -121.3815
# 1      1  0.09   20  24.7315  -81.0139
# 2      1  3.35  182  26.5700  -82.0370
# 3      1  0.19   45  26.5503  -81.9126
# 4      1  1.15  350  27.2530  -82.5396
# ...   ..   ...  ...      ...       ...
# 5166  12  7.70  900  33.1628  -89.4323
# 5167  12  3.82  200  33.2598  -89.2778
# 5168  12  2.61  200  33.4720  -89.0315
# 5169  12  3.23  125  32.5268  -89.1628
# 5170  12  5.07   50  34.7541  -87.0777
#
# [4873 rows x 5 columns]

# %%
# Choose our label
y = cleaned['adjusted magnitude']
y
# Out:
# 0       0
# 1       0
# 2       2
# 3       1
# 4       2
#        ..
# 5166    1
# 5167    1
# 5168    0
# 5169    1
# 5170    0
# Name: adjusted magnitude, Length: 4873, dtype: int64

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Create training and testing sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ### Apply Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Build Models

# %%
## Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_scaled, y_train)

print('Accuracy of Logistic Regression on training data', logreg.score(X_train_scaled, y_train))
print('Accuracy of Logistic Regression on testing data', logreg.score(X_test_scaled, y_test))
# Out:
# Accuracy of Logistic Regression on training data 0.6581828133552271
# Accuracy of Logistic Regression on testing data 0.6538146021328958

# %%
## Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train_scaled, y_train)

print('Accuracy of Decision Tree on training', dt.score(X_train_scaled, y_train))
print('Accuracy of Decision Tree on testing', dt.score(X_test_scaled, y_test))
# Out:
# Accuracy of Decision Tree on training 1.0
# Accuracy of Decision Tree on testing 0.6341263330598852

# %%
# Setting max decision tree depth to help avoid overfitting
dt2 = DecisionTreeClassifier(max_depth=3)
dt2.fit(X_train_scaled, y_train)
print('Accuracy of Decision tree on training', dt2.score(X_train_scaled, y_train))
print('Accuracy of Decision tree on testing', dt2.score(X_test_scaled, y_test))
# Out:
# Accuracy of Decision tree on training 0.685823754789272
# Accuracy of Decision tree on testing 0.6694011484823625

# %%
# K-nearest neighbor 
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train_scaled, y_train)
print('Accuracy of KNN on training', knn.score(X_train_scaled, y_train))
print('Accuracy of KNN on testing', knn.score(X_test_scaled, y_test))
# Out:
# Accuracy of KNN on training 0.7528735632183908
# Accuracy of KNN on testing 0.6620180475799836

# %%
# Linear Discriminant Analysis 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(X_train_scaled,y_train)
print('Accuracy of Linear Discriminant Analysis on training', lda.score(X_train_scaled, y_train))
print('Accuracy of Linear Discriminant Analysis on testing', lda.score(X_test_scaled, y_test))
# Out:
# Accuracy of Linear Discriminant Analysis on training 0.6390257252326218
# Accuracy of Linear Discriminant Analysis on testing 0.6300246103363413

# %%
# Gaussian Naive Bayes 
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train_scaled, y_train)
print('Accuracy of GNB on training', gnb.score(X_train_scaled, y_train))
print('Accuracy of GNB on testing', gnb.score(X_test_scaled, y_test))
# Out:
# Accuracy of GNB on training 0.6349206349206349
# Accuracy of GNB on testing 0.6472518457752255

# %%
# Support Vector Machine
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train_scaled, y_train)
print('Accuracy of SVM on training', svm.score(X_train_scaled, y_train))
print('Accuracy of SVM on testing', svm.score(X_test_scaled, y_test))
# Out:
# Accuracy of SVM on training 0.6625615763546798
# Accuracy of SVM on testing 0.6767842493847416

# %% [markdown]
# ### Save and load the best model

# %%
import pickle

# %%
pickle.dump(logreg, open('model.pkl','wb'))

# %%
# Loading model to compare the results
model = pickle.load( open('model.pkl','rb'))

# %% [markdown]
# ### Make Prediction on tornado category (magnitude)

# %%
user_input = [[1, 57, 9, 31.51, -93.92,]]
inputdf = pd.DataFrame(user_input,columns=["mo", "len", "wid", "slat", "slon"])
original_df = X.copy()
reference = original_df.append(inputdf).reset_index()
new_df = reference[["mo", "len", "wid", "slat", "slon"]]
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(new_df)
[list(scaled_df[len(scaled_df)-1])]
# scaled_df
# Out:
# [[0.0,
#   0.6906579425663395,
#   0.0027941633033219497,
#   0.6442445307708036,
#   0.24357558727190287]]

# %%
model.predict([list(scaled_df[len(scaled_df)-1])])
# Out:
# array([2])
